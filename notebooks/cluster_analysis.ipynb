# %% [markdown]
# # Cluster Analysis

# %%
from pathlib import Path
import sys

BASE_DIR =Path.cwd().resolve().parents[0] if Path.cwd() == 'notebooks' else Path.cwd()
sys.path.append(str(BASE_DIR/ 'scripts'))
from clustering_analysis import main
main()

# %% [markdown]
# ## Cluster Analysis Performes
# - Feature Engineering & Selection
# - Data Preprocessing
# - Dimensionality Reduction
# - Cluster Profiling
# - Automated Reporting
