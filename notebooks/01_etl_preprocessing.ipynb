# %% [markdown]
# # 01 ETL & Data Preprocessing
#
# This notebook covers extraction, cleaning, transformation, and integration of the six raw CSV files.

# %%
from pathlib import Path
import sys
BASE_DIR = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(BASE_DIR / 'scripts'))
from etl import main
main()

# %% [markdown]
# ## ETL steps performed
# - Loaded all raw CSV files
# - Standardized schema and parsed dates
# - Treated missing values and duplicates
# - Capped outliers using IQR
# - Created engineered fields such as `net_sales`, `age_group`, `ctr`, and `cost_per_conversion`
# - Built a customer master table for downstream analytics
