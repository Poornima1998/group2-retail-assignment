# %% [markdown]
# # Exploratory Data Analysis

# %%
from pathlib import Path
import sys
BASE_DIR = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(BASE_DIR / 'scripts'))
from eda import main
main()

# %% [markdown]
# ## Below points are analysed in EDA methods
# - Identify the highest-selling categories and months
# - Compare campaign ROI and cost efficiency by type
# - Review support issues with the highest operational burden
# - Examine which channels and payment methods dominate customer behavior
